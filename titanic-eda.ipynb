# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %% [markdown]
# # 0. start EDA

# %%
data=pd.read_csv('/kaggle/input/titanic/train.csv')
print(data.shape)
data.head()
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
msno.matrix(data)
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#目的変数の確認
fig,ax=plt.subplots()
data['Survived'].value_counts().plot.pie(ax=ax,autopct='%1.1f%%')
ax.set_title('Survived')
plt.show()

# %% [markdown]
# # 1. 'Sex'

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot(x=data['Sex'],hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %% [markdown]
# # 2. 'Pclass'

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True)
# Out:
# Survived    0    1  All
# Pclass
# 1          80  136  216
# 2          97   87  184
# 3         372  119  491
# All       549  342  891

# %%
fig,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot(x=data['Pclass'],hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True)
# Out:
# Pclass             1    2    3  All
# Sex    Survived
# female 0           3    6   72   81
#        1          91   70   72  233
# male   0          77   91  300  468
#        1          45   17   47  109
# All              216  184  491  891

# %% [markdown]
# # 3. 'Age'

# %%
print(data['Age'].agg([ 'mean', 'min', 'max']))
# Out:
# mean    29.699118
# min      0.420000
# max     80.000000
# Name: Age, dtype: float64

# %%
fig,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot(x=data['Pclass'],y=data['Age'], hue=data['Survived'],data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
sns.violinplot(x=data['Sex'],y=data['Age'], hue=data['Survived'],data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
plt.show()

# %%
fig,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
plt.show()

# %% [markdown]
# # 4. 'Embarked'

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True)
# Out:
# Sex             female      male       All
# Survived             0    1    0    1
# Embarked Pclass
# C        1           1   42   25   17   85
#          2           0    7    8    2   17
#          3           8   15   33   10   66
# Q        1           0    1    1    0    2
#          2           0    2    1    0    3
#          3           9   24   36    3   72
# S        1           2   46   51   28  127
#          2           6   61   82   15  164
#          3          55   33  231   34  353
# All                 81  231  468  109  889

# %%
fig,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot(x=data['Embarked'],data=data,ax=ax[0,0])
ax[0,0].set_title('Number of Embarked')
sns.countplot(x=data['Embarked'],hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot(x=data['Embarked'],hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked:Survived vs Dead')
sns.countplot(x=data['Embarked'],hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.show()

# %% [markdown]
# # 5. SibSp

# %%
pd.crosstab(data.SibSp,data.Survived)
# Out:
# Survived    0    1
# SibSp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0

# %%
fig,ax=plt.subplots(figsize=(20,8))
sns.barplot(x=data['SibSp'],y=data['Survived'],data=data,ax=ax)
ax.set_title('SibSp vs Survived')
plt.show()

# %%
pd.crosstab(data.SibSp,data.Pclass)
# Out:
# Pclass    1    2    3
# SibSp
# 0       137  120  351
# 1        71   55   83
# 2         5    8   15
# 3         3    1   12
# 4         0    0   18
# 5         0    0    5
# 8         0    0    7

# %% [markdown]
# # 6. 'Parch'

# %%
pd.crosstab(data.Parch,data.Pclass)
# Out:
# Pclass    1    2    3
# Parch
# 0       163  134  381
# 1        31   32   55
# 2        21   16   43
# 3         0    2    3
# 4         1    0    3
# 5         0    0    5
# 6         0    0    1

# %%
f,ax=plt.subplots(figsize=(20,8))
sns.barplot(x=data['Parch'],y=data['Survived'],data=data,ax=ax)
ax.set_title('Parch vs Survived')
plt.show()

# %% [markdown]
# # 7. 'Fare'

# %%
print(data['Fare'].agg([ 'mean', 'min', 'max']))
# Out:
# mean     32.204208
# min       0.000000
# max     512.329200
# Name: Fare, dtype: float64

# %%
fig,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()
# Out:
# /tmp/ipykernel_42/2423261522.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
# /tmp/ipykernel_42/2423261522.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
# ...

# %% [markdown]
# # feature engineering and data cleaning

# %%
#Ageの数値ごとの分類を特徴量として作成
data['Age_band']=0
data.loc[data['Age']<=16,'Age_band']=0
data.loc[(data['Age']>16)&(data['Age']<=32),'Age_band']=1
data.loc[(data['Age']>32)&(data['Age']<=48),'Age_band']=2
data.loc[(data['Age']>48)&(data['Age']<=64),'Age_band']=3
data.loc[data['Age']>64,'Age_band']=4
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Age_band
# 0      0  A/5 21171   7.2500   NaN        S         1
# 1      0   PC 17599  71.2833   C85        C         2

# %%
data['Age_band'].value_counts().to_frame()
# Out:
#           count
# Age_band
# 1           346
# 0           277
# 2           188
# 3            69
# 4            11

# %%
#性別ごとの平均生存率を作成してdataに結合
sex_survived=data[['Sex','Survived']].groupby(['Sex']).mean()
data=data.merge(sex_survived.rename(columns={'Survived':'sex_survived_mean'}),how='left',on=['Sex'])
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Age_band  sex_survived_mean
# 0      0  A/5 21171   7.2500   NaN        S         1           0.188908
# 1      0   PC 17599  71.2833   C85        C         2           0.742038

# %%
#カテゴリー変数を数値に変換
data['Sex'].replace(['male','female'],[0,1],inplace=True)
data['Embarked'].replace(['S','C','Q'],[0,1,2],inplace=True)
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
#
#       Ticket     Fare Cabin  Embarked  Age_band  sex_survived_mean
# 0  A/5 21171   7.2500   NaN       0.0         1           0.188908
# 1   PC 17599  71.2833   C85       1.0         2           0.742038

# %%
#数値データの相関関係を表示
data.drop(['Name','Age','Ticket','Fare','Cabin'],axis=1,inplace=True)
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >
